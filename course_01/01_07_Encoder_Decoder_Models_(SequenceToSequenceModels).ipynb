# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size=5> From above </font>
#
# <font size=4> *Sequence-to-sequence models are best suited for tasks revolving around generating new **sentences** depending on a given input*. </font>
#
# <font size=4> If it was about generating a new **phrase or a word** from a given sentence, **decoder** alone can do </font>
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <font size=6> Pretrained Models </font>
#
# <font size=5> From a pretrained models standpoint, there are encode-decoder models trained on specific text translation or summarization or new sentence generation objective based like BART, T5 etc,
#
# <font size=5> But we can combine our own encoder (say BERT) and decoder (say GPT) models (pretrained on different things like masked language modelling and next set of k words generation respectively) to come up with our own encoder<>decoder model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
