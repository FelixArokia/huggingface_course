# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size=5> The decoder uses its own produced output to poduce other outputs and hence the term **autoregressive**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size=5> ATTENTION LAYER </font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size=3> <u> this layer will tell the model to pay **specific attention to certain words in the sentence** you passed it (and more or less ignore the others) when dealing with the **representation of each word**. </u> </font>

# %% [markdown]
# ![image.png](attachment:image.png)
